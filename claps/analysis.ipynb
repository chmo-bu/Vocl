# %%
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import scipy
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5948\1871056646.py in <module>
#       2 from glob import glob
#       3 import matplotlib.pyplot as plt
# ----> 4 import scipy
#
# c:\users\mocha\ec463\lib\site-packages\scipy\__init__.py in <module>
#     134
#     135     # Allow distributors to run custom init code
# --> 136     from . import _distributor_init
#     137
#     138     from scipy._lib import _pep440
#
# c:\users\mocha\ec463\lib\site-packages\scipy\_distributor_init.py in <module>
#      62             os.chdir(libs_path)
#      63             for filename in glob.glob(os.path.join(libs_path, '*dll')):
# ---> 64                 WinDLL(os.path.abspath(filename))
#      65         finally:
#      66             os.chdir(owd)
#
# ...

# %%
dirs = glob("*.npy")
data = []
for d in dirs:
    data.append(np.load(d))

# %%
for d in data:
    t = np.arange(0, len(d))
    plt.plot(t, d)
    plt.figure()
